# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import spacy
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()# Visualise inside a notebook
import en_core_web_md
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaMulticore
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# %%
# Read the data
reports = pd.read_csv("scraped data for LDA/naturaldisaster1y.csv")
reports.head()
reports.info()

# Our spaCy model:
nlp = en_core_web_md.load()

# Tags we want to remove from the text
removal= ['ADV','PRON','CCONJ','PUNCT','PART','DET','ADP','SPACE', 'NUM', 'SYM']
tokens = []

reports['Description'] = reports['Description'].astype(str)
for description in nlp.pipe(reports['Description']):
   proj_tok = [token.lemma_.lower() for token in description if token.pos_ not in removal and not token.is_stop and token.is_alpha]
   tokens.append(proj_tok)

# Add tokens to new column
reports['tokens'] = tokens
reports['tokens']

# Create dictionary
# I will apply the Dictionary Object from Gensim, which maps each word to their unique ID:
dictionary = Dictionary(reports['tokens'])
print(dictionary.token2id)

# Filter dictionary
dictionary.filter_extremes(no_below=5, no_above=0.5, keep_n=1000)

# Create corpus
corpus = [dictionary.doc2bow(doc) for doc in reports['tokens']]

# LDA model building
lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=50, num_topics=10, workers = 4, passes=10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Time         680 non-null    object
#  1   Title        680 non-null    object
#  2   Description  680 non-null    object
#  3   Link         680 non-null    object
#  4   Datetime     680 non-null    object
# dtypes: object(5)
# memory usage: 26.7+ KB
# {'address': 0, 'advocacy': 1, 'conference': 2, 'conservative': 3, 'expand': 4, 'flex': 5, 'found': 6, 'friday': 7, 'group': 8, 'liberty': 9, 'muscle': 10, 'national': 11, 'nomination': 12, 'parent': 13, 'philadelphia': 14, 'political': 15, 'presidential': 16, 'republican': 17, 'reuters': 18, 'right': 19, 'rival': 20, 'year': 21, 'air': 22, 'canadian': 23, 'cause': 24, 'fourth': 25, 'half': 26, 'heat': 27, 'july': 28, 'long': 29, 'poor': 30, 'population': 31, 'precaution': 32, 'quality': 33, 'relentless': 34, 'urge': 35, 'wave': 36, 'weekend': 37, 'wildfire': 38, 'accident': 39, 'earthquake': 40, 'european': 41, 'food': 42, 'government': 43, 'import': 44, 'impose': 45, 'japan': 46, 'lifting': 47, 'major': 48, 'nuclear': 49, 'restriction': 50, 'say': 51, 'spokesperson': 52, 'trigger': 53, 'tsunami': 54, 'union': 55, 'welcome': 56, 'beach': 57, 'beatriz': 58, 'center': 59, 'city': 60, 'coast': 61, 'form': 62, 'head': 63, 'hurricane': 64, 'issue': 65, 'mexico': 66, 'nhc': 67, 'pacific': 68, 'popular': 69, 'prompt': 70, 'resort': 71, 'shore': 72, 'strengthen': 73, 'thursday': 74, 'warning': 75, 'admission': 76, 'comply': 77, 'conscious': 78, 'court': 79, 'diversity': 80, 'education': 81, 'high': 82, 'opportunity': 83, 'preserve': 84, 'program': 85, 'race': 86, 'ruling': 87, 'strike': 88, 'student': 89, 'supreme': 90, 'university': 91, 'value': 92, 'washington': 93, 'way': 94, 'americans': 95, 'chicago': 96, 'condition': 97, 'dangerous': 98, 'drift': 99, 'dull': 100, 'east': 101, 'loom': 102, 'midwest': 103, 'million': 104, 'prolonged': 105, 'sky': 106, 'smoke': 107, 'spot': 108, 'ten': 109, 'unhealthy': 110, 'abortion': 111, 'anti': 112, 'approval': 113, 'ban': 114, 'different': 115, 'doctor': 116, 'drug': 117, 'focus': 118, 'ingrid': 119, 'justify': 120, 'lawsuit': 121, 'mifepristone': 122, 'outcome': 123, 'physician': 124, 'pill': 125, 'place': 126, 'process': 127, 'prominent': 128, 'rest': 129, 'safety': 130, 'skop': 131, 'sue': 132, 'texas': 133, 'activity': 134, 'fill': 135, 'hover': 136, 'limit': 137, 'outdoor': 138, 'rage': 139, 'wednesday': 140, 'almond': 141, 'avocado': 142, 'bee': 143, 'chile': 144, 'colony': 145, 'country': 146, 'crop': 147, 'devastating': 148, 'event': 149, 'extreme': 150, 'flood': 151, 'global': 152, 'humble': 153, 'include': 154, 'key': 155, 'pollinator': 156, 'produce': 157, 'recent': 158, 'south': 159, 'weather': 160, 'begin': 161, 'biden': 162, 'case': 163, 'college': 164, 'current': 165, 'debt': 166, 'decide': 167, 'dispute': 168, 'end': 169, 'expect': 170, 'forgiveness': 171, 'important': 172, 'involve': 173, 'joe': 174, 'june': 175, 'lgbt': 176, 'number': 177, 'october': 178, 'plan': 179, 'practice': 180, 'president': 181, 'remain': 182, 'term': 183, 'adaptation': 184, 'aim': 185, 'canada': 186, 'climate': 187, 'drive': 188, 'fossil': 189, 'fuel': 190, 'impact': 191, 'launch': 192, 'melt': 193, 'mitigate': 194, 'permafrost': 195, 'reduce': 196, 'risk': 197, 'slow': 198, 'strategy': 199, 'tuesday': 200, 'warming': 201, 'attorney': 202, 'criminal': 203, 'department': 204, 'garland': 205, 'general': 206, 'house': 207, 'hunter': 208, 'impeachment': 209, 'investigation': 210, 'justice': 211, 'merrick': 212, 'probe': 213, 'representatives': 214, 'son': 215, 'threaten': 216, 'arkansas': 217, 'authority': 218, 'damage': 219, 'dead': 220, 'dozen': 221, 'hit': 222, 'home': 223, 'indiana': 224, 'leave': 225, 'monday': 226, 'people': 227, 'sunday': 228, 'thunderstorm': 229, 'tornado': 230, 'beat': 231, 'black': 232, 'congress': 233, 'crowded': 234, 'donald': 235, 'hurd': 236, 'join': 237, 'moderate': 238, 'party': 239, 'representative': 240, 'sole': 241, 'trump': 242, 'building': 243, 'injure': 244, 'kill': 245, 'matador': 246, 'northern': 247, 'official': 248, 'rip': 249, 'town': 250, 'arrival': 251, 'caribbean': 252, 'island': 253, 'lucia': 254, 'martinique': 255, 'nursery': 256, 'school': 257, 'season': 258, 'shut': 259, 'storm': 260, 'tomorrow': 261, 'tropical': 262, 'accord': 263, 'aileen': 264, 'canno ...

# %%
# Coherence score using C_v:
topics = []
score = []
for i in range(1,20,1):
   lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=10, num_topics=i, workers = 4, passes=10, random_state=100)
   cm = CoherenceModel(model=lda_model, texts = reports['tokens'], corpus=corpus, dictionary=dictionary, coherence='c_v')
   topics.append(i)
   score.append(cm.get_coherence())
_=plt.plot(topics, score)
_=plt.xlabel('Number of Topics')
_=plt.ylabel('Coherence Score')
plt.show()

# %%
coherence_lda = cm.get_coherence()
print('Coherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.325773393827236

# %%
# Optimal model
lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=100, num_topics=6, workers = 4, passes=100)

# %%
# Print topics
lda_model.print_topics(-1)
# Out:
# [(0,
#   '0.038*"wildfire" + 0.023*"reuters" + 0.014*"say" + 0.013*"canada" + 0.012*"province" + 0.011*"weather" + 0.011*"tuesday" + 0.010*"southern" + 0.010*"climate" + 0.010*"year"'),
#  (1,
#   '0.080*"earthquake" + 0.058*"turkey" + 0.035*"say" + 0.033*"syria" + 0.019*"devastating" + 0.016*"monday" + 0.016*"aid" + 0.015*"people" + 0.015*"week" + 0.014*"month"'),
#  (2,
#   '0.027*"reuters" + 0.018*"people" + 0.017*"city" + 0.016*"volcano" + 0.015*"thousand" + 0.014*"flooding" + 0.013*"cause" + 0.012*"earthquake" + 0.012*"landslide" + 0.012*"authority"'),
#  (3,
#   '0.029*"flooding" + 0.026*"rain" + 0.024*"reuters" + 0.019*"damage" + 0.015*"magnitude" + 0.015*"say" + 0.014*"earthquake" + 0.014*"people" + 0.013*"heavy" + 0.013*"home"'),
#  (4,
#   '0.046*"hurricane" + 0.034*"reuters" + 0.031*"storm" + 0.022*"say" + 0.021*"power" + 0.020*"florida" + 0.019*"people" + 0.019*"ian" + 0.014*"wednesday" + 0.014*"mexico"'),
#  (5,
#   '0.052*"president" + 0.030*"reuters" + 0.028*"washington" + 0.025*"biden" + 0.024*"say" + 0.023*"trump" + 0.021*"joe" + 0.021*"republican" + 0.021*"house" + 0.019*"donald"')]

# %%
# Visualize topics
lda_display = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1996023897342437126635330494" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el1996023897342437126635330494_data = {"mdsDat": {"x": [0.021968289018102553, 0.08892404895113051, 0.09864320923242612, -0.00650121692009491, -0.3121888735826765, 0.10915454330111249], "y": [0.25426521289818893, -0.10916569634883257, -0.07858836619871556, -0.033039504259565866, -0.03634251144498797, 0.002870865353912799], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [20.418522166141496, 19.564812552979923, 18.1633195589221, 15.956759591341449, 14.812574594294134, 11.084011536320897]}, "tinfo": {"Term": ["earthquake", "turkey", "hurricane", "president", "wildfire", "syria", "storm", "washington", "flooding", "biden", "power", "trump", "joe", "republican", "devastating", "ian", "rain", "florida", "house", "donald", "aid", "magnitude", "damage", "turkish", "mexico", "strike", "syrian", "city", "volcano", "people", "turkey", "syria", "devastating", "syrian", "turkish", "hold", "devastate", "erdogan", "tayyip", "humanitarian", "victim", "nations", "homeless", "spokesperson", "istanbul", "rebel", "aleppo", "antakya", "northwestern", "syrians", "relative", "save", "building", "aid", "shelter", "northwest", "family", "earthquake", "response", "foreign", "border", "rubble", "huge", "month", "disaster", "say", "strike", "week", "monday", "government", "massive", "kill", "help", "people", "southern", "country", "hit", "reuters", "region", "official", "tuesday", "hurricane", "ian", "power", "mexico", "puerto", "rico", "fiona", "outage", "landfall", "small", "wide", "cuba", "jury", "florida", "san", "fort", "protect", "accuse", "houston", "myers", "hush", "trial", "lawsuit", "grid", "juan", "nicole", "churn", "slam", "vehicle", "wake", "center", "estimate", "storm", "tropical", "business", "atlantic", "expect", "destruction", "coast", "tornado", "hit", "local", "reuters", "people", "leave", "cause", "city", "home", "island", "wednesday", "say", "thursday", "monday", "kill", "damage", "week", "official", "south", "magnitude", "australia", "pakistan", "flee", "sydney", "inundate", "tremor", "evening", "flash", "dump", "appeal", "property", "school", "downpour", "organization", "lash", "nation", "feel", "snow", "district", "tsunami", "threat", "river", "road", "medium", "return", "look", "unleash", "heavy", "shake", "flooding", "rain", "report", "damage", "torrential", "trigger", "warn", "high", "major", "flood", "strike", "island", "region", "strong", "resident", "home", "reuters", "bring", "thursday", "storm", "people", "say", "friday", "authority", "earthquake", "country", "tuesday", "cause", "wildfire", "canada", "europe", "rage", "temperature", "level", "alberta", "heatwave", "smoke", "battle", "ukraine", "firefighter", "summer", "canadian", "drought", "category", "activity", "nhc", "ottawa", "blaze", "spain", "portugal", "hot", "chile", "story", "event", "tackle", "britain", "paragraph", "quality", "abortion", "heat", "france", "air", "change", "risk", "record", "alert", "russian", "climate", "part", "control", "weather", "province", "reuters", "southern", "year", "say", "tuesday", "force", "country", "day", "thursday", "washington", "biden", "trump", "joe", "republican", "donald", "federal", "representatives", "party", "court", "presidential", "kevin", "president", "mccarthy", "congress", "speaker", "ceiling", "republicans", "default", "white", "senate", "nomination", "senator", "ron", "conservative", "lawmaker", "economic", "debt", "committee", "bill", "china", "house", "election", "vote", "administration", "governor", "state", "plan", "spending", "support", "reuters", "say", "wednesday", "tuesday", "new", "accord", "friday", "thursday", "monday", "landslide", "eruption", "political", "park", "rebuild", "emerge", "displace", "pull", "camp", "batter", "kamchatka", "ask", "cianjur", "auckland", "java", "tent", "tokyo", "drift", "hope", "peninsula", "black", "history", "philippines", "ankara", "volcano", "work", "close", "japan", "bad", "near", "zealand", "big", "indonesia", "typhoon", "rescue", "evacua ...

# %%
# Save the report
pyLDAvis.save_html(lda_display, 'saved html/naturaldisaster1y.html')

# %%
# Access the topic coordinates
topic_coordinates = lda_display.topic_coordinates

# Access the ordering of topics in the visualization
topic_order = lda_display.topic_order
print (topic_coordinates)

# Convert topic coordinates to NumPy array
topic_coordinates_array = topic_coordinates.values

# Create a scatter plot of the topic coordinates
plt.scatter(topic_coordinates_array[:, 0], topic_coordinates_array[:, 1], marker='o', c='blue', s=100, alpha=0.6)

# Add labels to the scatter plot
for topic, (x, y, *_) in enumerate(topic_coordinates_array):
    plt.text(x, y, f'Topic {topic}', fontsize=10, ha='center', va='center')

# Set plot title and axis labels
plt.title('Topic Coordinates')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
# Out:
#               x         y  topics  cluster       Freq
# topic
# 1      0.021968  0.254265       1        1  20.418522
# 4      0.088924 -0.109166       2        1  19.564813
# 3      0.098643 -0.078588       3        1  18.163320
# 0     -0.006501 -0.033040       4        1  15.956760
# 5     -0.312189 -0.036343       5        1  14.812575
# 2      0.109155  0.002871       6        1  11.084012
# Text(0, 0.5, 'Y Coordinate')

# %%
reports['topic'] = [sorted(lda_model[corpus][text])[0][0] for text in range(len(reports['Description']))]
reports.topic.value_counts()
# Out:
# topic
# 0    488
# 1     75
# 2     42
# 3     36
# 4     28
# 5     11
# Name: count, dtype: int64

# %%
# Associate topics with datetime
reports['topic'] = [sorted(lda_model[corpus[text]], key=lambda x: x[1], reverse=True)[0][0] for text in range(len(reports['Description']))]
reports['topic'] = reports['topic'].astype(int)

# Merge topics with corresponding datetime
topics = lda_model.print_topics(num_topics=7, num_words=5)
topics_dict = {topic[0]: topic[1] for topic in topics}
reports['topic_words'] = reports['topic'].map(topics_dict)

# Resulting DataFrame with topics associated with datetime
print(reports[['Datetime', 'topic', 'topic_words']])
# Out:
#                       Datetime  topic
# 0    2023-06-30 18:50:00+00:00      5  \
# 1    2023-06-30 14:18:00+00:00      0
# 2    2023-06-30 08:47:00+00:00      1
# 3    2023-06-30 01:01:00+00:00      4
# 4    2023-06-29 19:07:00+00:00      3
# ..                         ...    ...
# 675  2022-07-03 08:49:00+00:00      2
# 676  2022-07-03 05:38:00+00:00      3
# 677  2022-07-02 19:22:00+00:00      3
# 678  2022-07-01 15:21:00+00:00      2
# 679  2022-07-01 02:16:00+00:00      4
#
#                                            topic_words
# 0    0.052*"president" + 0.030*"reuters" + 0.028*"w...
# 1    0.038*"wildfire" + 0.023*"reuters" + 0.014*"sa...
# 2    0.080*"earthquake" + 0.058*"turkey" + 0.035*"s...
# 3    0.046*"hurricane" + 0.034*"reuters" + 0.031*"s...
# 4    0.029*"flooding" + 0.026*"rain" + 0.024*"reute...
# ..                                                 ...
# 675  0.027*"reuters" + 0.018*"people" + 0.017*"city...
# 676  0.029*"flooding" + 0.026*"rain" + 0.024*"reute...
# 677  0.029*"flooding" + 0.026*"rain" + 0.024*"reute...
# 678  0.027*"reuters" + 0.018*"people" + 0.017*"city...
# 679  0.046*"hurricane" + 0.034*"reuters" + 0.031*"s...
#
# [680 rows x 3 columns]

# %%
# Group the data by datetime and topic
grouped_data = reports.groupby(['Datetime', 'topic']).size().unstack().fillna(0)

# Plotting the distribution of topics over time
grouped_data.plot(kind='line', figsize=(30, 10), marker='o')

# Customize the plot
plt.title('Topic Distribution Over Time', fontsize=25)
plt.xlabel('Datetime', fontsize=20)
plt.ylabel('Topic Count', fontsize=20)
plt.legend(title='Topic', loc='upper right', fontsize=20)

# Show the plot
plt.show()
